# %%
# 문자열(string)은 연속된 문자들의 나열이다.

"Life is too short, You need Python"
"a"
"123"

# %%
# 문자열 더해서 연결하기

head = "Python"
tail = " is fun!"
head + tail
# 'Python is fun!'

# %%
# 문자열 곱하기
a = "python"
a *= 2
# 'pythonpython'

# %%
# 문자열 곱하기를 응용해 보자.

print("=" * 50)
print("My Program")
print("=" * 50)
# Out:
# ...
# My Program
# ...

# %%
# 문자열 길이 구하기

a = "Life is too short"
len(a)
17
# Out:
# 17
